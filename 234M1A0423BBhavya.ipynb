# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Personal\\Downloads//bank-selected-columns.csv")
print(df.head(10))
print(df.tail(11))
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
# 9   28    services    single  secondary      no     5090     yes   no
#
#    contact  day
# 0  unknown    5
# 1  unknown    5
# 2  unknown    5
# 3  unknown    5
# 4  unknown    5
# 5  unknown    5
# 6  unknown    6
# 7  unknown    6
# 8  unknown    6
# 9  unknown    6
# ...

# %%
df.shape
# Out:
# (11162, 10)

# %%
df.rename(columns={"housing":"HOUSING"},inplace=True)

# %%
df.head(2)
# Out:
#    age     job  marital  education default  balance HOUSING loan  contact  day
# 0   59  admin.  married  secondary      no     2343     yes   no  unknown    5
# 1   56  admin.  married  secondary      no       45      no   no  unknown    5

# %%
df.rename(columns={"housing":"HOUSING","age":"AGE","job":"JOB","martial":"MARTIAL","education":"EDUCATION","default":"DEFAULT","balance":"BALANCE","loan":"LOAN","contact":"CONTACT","day":"DAY"},inplace=True)
df.head()
# Out:
#    AGE         JOB  marital  EDUCATION DEFAULT  BALANCE HOUSING LOAN  CONTACT  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    DAy
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(2,2))
plt.barh(df['EDUCATION'],df['DAy'])
plt.show()

# %%
#bar graph interpretations
#1.construct bar graph between education and day
#2.construct all categories under education vs day i observed

# %%
plt.figure(figsize=(3,4))
plt.hist(df.loc[0:11:,"DAy"],bins=5)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df["DAy"]=scaler.fit_transform(df[['DAy']])

# %%
df.head()
# Out:
#    AGE         JOB  marital  EDUCATION DEFAULT  BALANCE HOUSING LOAN  CONTACT  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#         DAy
# 0 -1.265746
# 1 -1.265746
# 2 -1.265746
# 3 -1.265746
# 4 -1.265746

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["HOUSING"]=le.fit_transform(df[["HOUSING"]])
# Out:
# C:\Users\Personal\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    AGE         JOB  marital  EDUCATION DEFAULT  BALANCE  HOUSING LOAN  \
# 0   59      admin.  married  secondary      no     2343        1   no
# 1   56      admin.  married  secondary      no       45        0   no
# 2   41  technician  married  secondary      no     1270        1   no
# 3   55    services  married  secondary      no     2476        1   no
# 4   54      admin.  married   tertiary      no      184        0   no
#
#    CONTACT  DAy
# 0  unknown    4
# 1  unknown    4
# 2  unknown    4
# 3  unknown    4
# 4  unknown    4

# %%
from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder(sparse_output=False)
encoded=one.fit_transform(df[['DEFAULT']])
encoded_df=pd.DataFrame(encoded,columns=one.get_feature_names_out(["DEFAULT"]))
print(encoded_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 one=OneHotEncoder(sparse_output=False)
# ----> 3 encoded=one.fit_transform(df[['DEFAULT']])
#       4 encoded_df=pd.DataFrame(encoded,columns=one.get_feature_names_out(["DEFAULT"]))
#       5 print(encoded_df)
#
# NameError: name 'df' is not defined

# %%
#model building -linear regression models

# %%
#step1:importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#step2:uploading dataset
rdf=pd.read_csv("C:\\Users\\Personal\\Downloads//bank-selected-columns.csv")

# %%
rdf.head()
rdf.tail()
rdf.info()
rdf.shape
rdf.describle()

# %%
#step5: Visulalization of dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(3,4))
plt.scatter(rdf["AGE"],rdf["BALANCE"],color="red",s=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(3,4))
# ----> 4 plt.scatter(rdf["AGE"],rdf["BALANCE"],color="red",s=60)
#       5 plt.show()
#
# NameError: name 'rdf' is not defined

# %%
ftom sklearn.metrics import r2_score
import numpy as np
mae=mean_absolute_error(y_test,y_pre)
mse=mean_standard_error(
